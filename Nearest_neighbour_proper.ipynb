# %%
import cv2
import numpy as np
from numpy import zeros, newaxis
from matplotlib import pyplot as plt

# %%
import math

# %%
a=np.asarray(img)

# %%
img = cv2.imread('cells.png',1)
plt.imshow(img)
plt.show()

# %%
a.shape
# Out:
# (254, 256, 3)

# %%
w,h,c = a.shape

# %%
fx=0.5
fy=0.5

# %%
a
# Out:
# array([[[214, 214, 214],
#         [219, 219, 219],
#         [224, 224, 224],
#         ...,
#         [ 31,  31,  31],
#         [ 37,  37,  37],
#         [ 43,  43,  43]],
#
#        [[213, 213, 213],
#         [217, 217, 217],
#         [222, 222, 222],
#         ...,
#         [ 27,  27,  27],
#         [ 32,  32,  32],
#         [ 36,  36,  36]],
#
#        [[216, 216, 216],
#         [219, 219, 219],
#         [221, 221, 221],
#         ...,
#         [ 22,  22,  22],
#         [ 27,  27,  27],
#         [ 30,  30,  30]],
#
#        ...,
#        [[179, 179, 179],
#         [179, 179, 179],
#         [179, 179, 179],
#         ...,
#         [207, 207, 207],
#         [207, 207, 207],
#         [207, 207, 207]],
#
#        [[174, 174, 174],
#         [175, 175, 175],
#         [177, 177, 177],
#         ...,
#         [207, 207, 207],
#         [207, 207, 207],
#         [207, 207, 207]],
#
#        [[169, 169, 169],
#         [171, 171, 171],
#         [174, 174, 174],
# ...

# %%
new_w=int(w*fx)
new_h=int(h*fy)

# %%
b=np.zeros(shape=(new_h,new_w,c))

# %%
for i in range(new_w):
    for j in range(new_h):
        b[j,i][:]=a[int(i/fx)][int(j/fy)][:]

# %%
plt.imshow(b)
plt.show()
