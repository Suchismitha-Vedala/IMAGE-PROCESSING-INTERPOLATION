# %%
import cv2
import numpy as np
from numpy import zeros, newaxis
from matplotlib import pyplot as plt
np.seterr(divide='ignore', invalid='ignore')
img = cv2.imread("grape.png")

# %%
import math

# %%
arr=np.asarray(img)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
w1,h1,z= img.shape

# %%
fx=0.5
fy=0.5

# %%
w2=int(fx*w1)
h2=int(fy*h1)

# %%
x_ratio = w1/w2 
y_ratio = h1/h2

# %%
temp=np.zeros(shape=(w2,h2))

# %%
M=np.zeros(shape=(w2,h2))

# %%
M.shape
# Out:
# (89, 81)

# %%
for i in range(w1):
    for j in range(h1):
        temp[int(fx*i)][int(fy*j)]=arr[i][j][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-49357d884bbb> in <module>()
#       1 for i in range(w1):
#       2     for j in range(h1):
# ----> 3         temp[int(fx*i)][int(fy*j)]=arr[i][j][1]
#
# IndexError: index 89 is out of bounds for axis 0 with size 89

# %%
x_scale=np.round(w2/w1)
y_scale=np.round(h2/h1)

# %%
i=0
j=0
for i in range(w2-1):
    for j in range(h2-1):
        if (j>=(h2-2) or (i>=(w2-2))):
            M[i+1][j+1]=arr[1+int((i-2)/x_scale)][1+int((j-2)/y_scale)][1]
        else:
            M[i+1][j+1]=arr[1+int(np.floor(i/x_scale))][1+int(np.floor(j/y_scale))][1]

# %%
N=M[:, :, newaxis]
N.shape
# Out:
# (89, 81, 1)

# %%
plt.imshow(M)

plt.show()

# %%
img = cv2.imread('grape.png',0)
plt.imshow(img)
plt.show()

# %%
double px, py ; 
for i in range(h2):
    for j in range(w2):
        px = Math.floor(j*fx)
        py = Math.floor(i*y_ratio)
for (int i=0;i<h2;i++) {
        for (int j=0;j<w2;j++) {
            px = math.floor(j*fx) ;
            py = math.floor(i*fy) ;
            temp[(i*w2)+j] = pixels[(int)((py*w1)+px)] ;
        }
    }
    return temp ;
