# %%
import cv2
import numpy as np
import math
from numpy import zeros, newaxis
from matplotlib import pyplot as plt

# %%
img = cv2.imread('cells.png',1)
plt.imshow(img)
plt.show()

# %%
a=np.asarray(img)
w,h,c = a.shape

# %%
a.shape
# Out:
# (254, 256, 3)

# %%
fx=2
fy=2

# %%
new_w=int(w*fx)
new_h=int(h*fy)
b=np.zeros(shape=(new_h,new_w,c))

# %%
a[253,0]
# Out:
# array([169, 169, 169], dtype=uint8)

# %%
for i in range(new_w):
    x1=int(np.floor(i/fx))
    x2=int(np.ceil(i/fx))
    if (x1 == 0):
        x1=1
    x= int((i/fx)%1)
    for j in range(new_h):
        y1=int(np.floor(j/fy))
        y2=int(np.ceil(j/fy))
        if (y1 == 0):
            y1=1
        y= int((j/fy)%1)
        ctl = a[x1,y1,:]
        cbl = a[x2,y1,:]
        
        ctr = a[x1,y2,:]
        cbr = a[x2,y2,:]
        
        y = int((j/fx)%1)
        tr = ((ctr*y)+(ctl*(1-y)))
        br = ((cbr*y)+(cbl*(1-y)))
        '''
        b[j,i,:] = ((br*x)+(tr*(1-x)))
    
'''

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-4dad1d861dca> in <module>()
# ----> 1 print ct1
#
# NameError: name 'ct1' is not defined

# %%
b.shape
# Out:
# (512, 508, 3)

# %%
a.shape
# Out:
# (254, 256, 3)

# %%
plt.plot(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fa1a84f684ae> in <module>()
# ----> 1 plt.plot(b)
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /Users/suchi/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
# --> 247                              "shapes {} and {}".format(x.shape, y.shape))
#     248
#     249         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (512,) and (512, 508, 3)

# %%
b=a

# %%
a.shape

# %%
x=np.asarray(274.5)

# %%
y=np.asarray(256)

# %%
x0 = np.floor(x).astype(int)
x1 = x0 + 1
y0 = np.floor(y).astype(int)
y1 = y0 + 1

# %%
print x0,y0,x1,y1

# %%
x0 = np.clip(x0, 0, img.shape[1]-1);
x1 = np.clip(x1, 0, img.shape[1]-1);
y0 = np.clip(y0, 0, img.shape[0]-1);
y1 = np.clip(y1, 0, img.shape[0]-1);

# %%
Ia = img[ y0, x0 ]
Ib = img[ y1, x0 ]
Ic = img[ y0, x1 ]
Id = img[ y1, x1 ]

# %%
wa = (x1-x) * (y1-y)
wb = (x1-x) * (y-y0)
wc = (x-x0) * (y1-y)
wd = (x-x0) * (y-y0)

# %%
wa*Ia + wb*Ib + wc*Ic + wd*Id

# %%
for i in range(w):
    for j in range(h):
        b[j,i,:]=a[]

# %%
for i in range(new_w):
    for j in range(new_h):
        x1=int(fx*(np.floor(i/fx)))
        x2=int(fx*(np.ceil(i/fx)))
        y1=int(fy*(np.floor(j/fy)))
        y2=int(fy*(np.ceil(j/fy)))
        b[j,i][:]=((a[x1][y1][:]*(y2-j)*(x2-i))+(a[x1][y2][:]*(j-y1)*(x2-i))+(a[x2][y1][:]*(y2-j)*(i-x1))+(a[x2][y2][:]*(i-x1)*(j-y1)))/((x2-x1)*(y2-y1))
